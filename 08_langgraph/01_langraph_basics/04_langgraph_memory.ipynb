# %% [markdown]
# # Checkpoint로 이어지는 LangGraph 대화 기억
#
# LangGraph의 **Persistence**는 한 번의 그래프 실행이 끝난 뒤에도 State를 보존하는 기능이다. 이전 대화를 State에 저장하면 다음 질문에서 같은 대화를 이어 갈 수 있다.
#
# ## 먼저 구분할 용어
#
# 대화 기억은 모델이 내용을 내부에 외우는 기능이 아니다. LangGraph runtime이 현재 작업 데이터인 State를 저장하고, 다음 호출 전에 다시 불러오는 구조이다.
#
# - **State**: Node들이 현재 실행에서 함께 읽고 갱신하는 작업 데이터이다. 이 실습에서는 `messages`가 대화 이력이다.
# - **Checkpointer**: State를 저장하고 불러오는 저장 관리자이다.
# - **Checkpoint**: 특정 실행 단계에서 저장한 State snapshot 하나이다.
# - **thread**: 같은 대화에 속한 Checkpoint history이다.
# - **thread_id**: 저장하거나 불러올 thread를 지정하는 key이다. 사용자 인증을 담당하지 않는다.
# - **StateSnapshot**: 저장된 Checkpoint를 `get_state()`로 읽었을 때 반환되는 조회 객체이다.
#
# 핵심 흐름은 `thread_id로 thread 선택 → Checkpointer가 최신 Checkpoint 복구 → State에 새 입력 병합 → 그래프 실행 → 새 Checkpoint 저장` 순서이다.
#
# `InMemorySaver`는 Checkpointer의 한 구현이며 Checkpoint를 현재 Python 프로세스의 RAM에 저장한다. 프로세스가 끝나면 사라지므로 수업과 개발에 적합하고, 운영 환경에서는 DB 기반 Checkpointer를 사용한다.
#
# Checkpoint는 한 thread 안에서 이어지는 **단기 기억**을 담당한다. 여러 thread에서 공유할 사용자 선호나 장기 정보는 Store가 담당한다.
#
# ### 대화 이어가기와 중단된 실행 재개의 차이
#
# 이 실습의 이어가기는 같은 `thread_id`로 새 `graph.invoke()`를 호출해 과거 State 위에서 **새 Turn을 시작하는 방식**이다. 중단된 Node를 `Command(resume=...)`로 재개하는 Human-in-the-loop의 resume와는 다르며, 후자는 다음 노트북에서 다룬다.
#
# ## 이번 실습에서 확인할 것
#
# 같은 `thread_id`를 재사용하면 이전 `messages`가 복구되고, 다른 `thread_id`를 사용하면 대화가 분리되는지 비교한다. 마지막에는 `graph.get_state()`로 저장된 최신 State를 직접 읽는다.

# %% [markdown]
# ## 실행 환경 준비
#
# Persistence가 있는 Tool loop를 실행할 패키지를 현재 Jupyter 커널 환경에 설치한다.
#
# - `langgraph`: 그래프와 `InMemorySaver`를 제공한다.
# - `langchain-openai`: OpenAI Chat Model을 연결한다.
# - `langchain-tavily`: 검색 Tool을 제공한다.
# - `python-dotenv`: `.env`의 설정을 환경 변수로 불러온다.
#
# DB에 저장하는 운영용 Checkpointer는 별도 패키지가 필요하지만, 이 실습은 RAM에 저장하는 `InMemorySaver`만 사용한다.

# %%
# %pip install -U langgraph langchain-openai langchain-tavily python-dotenv
# Out:
# Requirement already satisfied: langgraph in C:\conda\envs\llm_env\Lib\site-packages (1.2.11)
# Requirement already satisfied: langchain-openai in C:\conda\envs\llm_env\Lib\site-packages (1.5.1)
# Requirement already satisfied: langchain-tavily in C:\conda\envs\llm_env\Lib\site-packages (0.2.18)
# Requirement already satisfied: python-dotenv in C:\conda\envs\llm_env\Lib\site-packages (1.2.3)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph) (1.5.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\conda\envs\llm_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\conda\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\conda\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in C:\conda\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\conda\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\conda\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\conda\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\conda\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: certifi in C:\conda\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\conda\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in C:\conda\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\conda\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\conda\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\conda\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\conda\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-openai) (2.53.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\conda\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in C:\conda\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: regex in C:\conda\envs\llm_env\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-tavily) (3.14.3)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in C:\conda\envs\llm_env\Lib\site-packages (from langchain-tavily) (1.3.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\conda\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\conda\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\conda\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\conda\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\conda\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\conda\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\conda\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.24.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\conda\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\conda\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.7.0)
# Requirement already satisfied: colorama in C:\conda\envs\llm_env\Lib\site-packages (from tqdm>4->openai<4.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 모델·검색 인증과 선택 추적 설정
#
# `.env`는 API key와 모델 ID를 코드 밖에서 관리하는 설정 파일이다. 아래 셀은 비밀값을 출력하지 않고 누락된 환경 변수의 이름만 검사한다.
#
# - `OPENAI_API_KEY`: Chat Model 호출에 필요한 필수값이다.
# - `TAVILY_API_KEY`: 검색 Tool 호출에 필요한 필수값이다.
# - `OPENAI_CHAT_MODEL`: 호출할 모델 ID이며 없으면 수업용 기본값을 사용한다.
# - `LANGSMITH_API_KEY`: 실행 추적에 사용하는 선택값이다. 없어도 그래프와 Checkpoint 실습은 실행된다.
#
# `setdefault()`는 환경 변수가 없을 때만 기본값을 넣는다. 따라서 이미 정해진 LangSmith 설정을 덮어쓰지 않는다.

# %%
import os
from dotenv import find_dotenv, load_dotenv

dotenv_path = find_dotenv(usecwd=True)
load_dotenv(
    dotenv_path,
    override=False,
)

if os.getenv("LANGSMITH_API_KEY"):
    os.environ.setdefault("LANGSMITH_TRACING", "true")
    os.environ.setdefault("LANGSMITH_PROJECT", "langgraph-memory")

OPENAI_CHAT_MODEL = os.getenv("OPENAI_CHAT_MODEL", "gpt-5.6-luna")

# %% [markdown]
# ## 그래프 밖에서 검색 Tool 점검하기
#
# `TavilySearch`는 검색어를 받아 웹 검색 결과를 반환하는 Tool이다. Checkpoint 실습에 들어가기 전에 Tool만 직접 호출해 인증·네트워크·반환 구조를 먼저 확인한다.
#
# `max_results=2`는 한 번의 검색에서 가져올 최대 결과 수이다. 결과 수를 줄이면 이후 ToolMessage에 저장되는 검색 문맥이 불필요하게 커지는 것을 막을 수 있다.

# %%
from langchain_tavily import TavilySearch

tavily_tool = TavilySearch(max_results=2)

tavily_tool.invoke({
    "query": "지금 서울 날씨는?"
})
# Out:
# {'query': '지금 서울 날씨는?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.aqi.in/weather/ko/south-korea/seoul/seoul',
#    'title': 'Seoul 날씨 상태: 기온 | 30일 예보',
#    'content': '3.6 kmph /  SW\n\n마지막 업데이트:  17 Aug 2026, 07:57 PM\n\n## FAQs About Seoul Weather Conditions\n\n1. Seoul의 오늘 18 8월 2026 현재 기온은 얼마인가요?\n\nSeoul의 현재 기온은 22°C이며, 체감 온도는 27°C입니다. 오늘 예보에 따르면 최고 기온은 31°C, 최저 기온은 22°C로 04:30 AM 18 8월 2026 기준 하루 동안 9도의 기온차가 있습니다.\n\n2. Seoul의 오늘 현재 날씨 매개변수는 무엇인가요?\n\n04:30 AM 18 8월 2026 기준 Seoul의 현재 날씨 상태에 대한 전체 개요는 다음과 같습니다:\n상태 : Fog\n기온 : 22°C 쾌적한 (체감 27°C)\n습도 : 98%\n풍속 : 3.6 km/h (SSE 방향, 163도), 돌풍 1 m/s\nUV 지수 : 0 (Low\n기압 : 1008 mb\n운량 : 100%\n시정 : 0 km\n강수량 : 0 mm (강우 확률 38%) [...] 04:30 AM 18 8월 2026부터 Seoul의 10일 예보는 다음 추세를 보입니다:\n오늘 (8월 18) : 기온 26°C, 습도 75% 및 Sunny 상태.\n수요일 (8월 19) : 기온 26°C, 습도 73% 및 Overcast 상태.\n목요일 (8월 20) : 기온 26°C, 습도 72% 및 Overcast 상태.\n금요일 (8월 21) : 기온 23°C, 습도 88% 및 Rain Shower 상태.\n토요일 (8월 22) : 기온 25°C, 습도 84% 및 Overcast 상태.\n일요일 (8월 23) : 기온 26°C, 습도 82% 및 Rain Shower 상태.\n월요일 (8월 24) : 기온 23°C, 습도 94% 및 Rain Showers 상태.\n화요일 (8월 25) : 기온 23°C, 습도 98% 및 Rain Showers 상태.\n수요일 (8월 26) : 기온 24°C, 습도 74% 및 Rain Showers 상태. [...] Seoul Weather Conditions\n\nCurrent Temperature Level\n\nfog\n\n온도 27°C\n\nChances of Rain42%\n\n37AQI\n\n깨끗한 공기.\n\n습도\n\n98%\n\n높은 습도는 불쾌감을 유발할 수 있습니다.\n\nfog\nfog\nfog\nmist\npatchy rain possible\npatchy rain possible\npatchy rain possible\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nclear\nclear\nclear\nclear\npartly cloudy\novercast\nhaze\nhaze',
#    'score': 0.81875163,
#    'raw_content': None,
#    'id': '98641a-00'},
#   {'url': 'https://korean.visitseoul.net/weather',
#    'title': '서울 실시간 날씨 정보 | 서울 공식 관광정보 웹사이트',
#    'content': '| 항목 | 오늘 : 2026-08-08 | 내일 : 2026-08-09 | 모레 : 2026-08-10 |\n| 날씨 | 구름많고 한때 소나기  구름많고 한때 소나기 | 맑음  맑음 | 구름많음  구름많음 |\n| 최저/최고기온 (℃) | 25℃ / 35℃ | 25℃ / 33℃ | 25℃ / 33℃ |\n| 강수확률 | 0% / 60% | 0% / 10% \n\n#### 대기오염 상세\n\n대기오염 상세 표 : 항목(오늘예보, 내일예보, 모레예보), 미세먼지(PM10), 초미세먼지(PM2.5)\n\n| 항목 | 오늘예보 | 내일예보 | 모레예보 |\n| 미세먼지 (PM10) | 미세먼지좋음 좋음 | 미세먼지좋음 좋음 | 미세먼지좋음 좋음 |\n| 초미세먼지 (PM2.5) | 초미세먼지좋음 좋음 | 초미세먼지좋음 좋음 | 초미세먼지좋음 좋음 |\n\n#### 주간예보\n\n주간예보 표 : 항목별 날짜, 날씨, 최저/최고기온(℃) [...] | 항목 | 2026-08-08 | 2026-08-09 | 2026-08-10 | 2026-08-11 | 2026-08-12 |\n| 날씨 | 구름많고 한때 소나기 구름많고 한때 소나기 | 맑음 맑음 | 구름많음 구름많음 | 맑음 맑음 | 맑음 맑음 |\n| 최저/최고기온 (℃) | 25℃ / 35℃ | 25℃ / 33℃ | 25℃ / 33℃ | 25℃ / 35℃ | 25℃ / 34℃ |\n\n제공 : 케이웨더(Kweather) [...] Family Site\n\nFamily Site; "메뉴 열기") \n\n 파트너스\n STO 소개\n 의료관광\n 서울관광 아카이브\n 서울관광플라자\n 디스커버서울패스\n 서울스테이\n 다누림관광\n 서울등산관광\n 서울컨벤션뷰로\n 서울컬쳐라운지\n Visit Seoul API\n SEOUL BLEISURE\n 서울미식주간\n\n전체보기메뉴 열기\n\n전체보기메뉴 열기\n\n## visitseoul.net\n\n### 검색순위\n\n### 나의찜하기\n\n찜하기는 관심 있는 여행 정보를 저장하여 서울의 주요 지역별로 탐색할 수 있는 기능입니다.\n\n나의 찜한 목록 바로가기\n\n서울의 날씨\n\n홈 >  여행정보 >  서울의 날씨\n\n서울의 날씨\n\n#### 3일 예보\n\n3일 예보 표 : 항목별(오늘, 내일, 모레) 날짜, 날씨, 최저/최고기온(℃), 강수확률',
#    'score': 0.70336664,
#    'raw_content': None,
#    'id': '0f88e6-01'}],
#  'response_time': 0.0,
#  'request_id': 'a32ea5c1-2049-42ec-b3ce-6cf77ad71bbc'}

# %% [markdown]
# ## Chat Model에 검색 Tool 사용법 연결하기
#
# `bind_tools()`는 Chat Model에 Tool의 이름·설명·입력 schema를 알려 준다. 모델은 검색이 필요하다고 판단하면 `tool_calls`를 포함한 `AIMessage`를 반환한다.
#
# 이 단계는 Tool을 **실행**하지 않는다. 실제 Tool 호출은 뒤에서 등록할 `ToolNode`가 담당한다.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model_name=OPENAI_CHAT_MODEL,
    use_responses_api=True
)

tools = [tavily_tool]

llm_with_tools = llm.bind_tools(tools)

# %% [markdown]
# ## Checkpoint 대화 기억을 완성할 네 구성 요소
#
# 여기까지 만든 `llm_with_tools`는 Tool 요청을 만들 수 있지만, 대화 이력을 저장하거나 다음 호출에서 복구하지는 않는다. 기억이 있는 Tool loop를 만들려면 다음 네 구성 요소를 연결해야 한다.
#
# 1. `State`: 저장할 `messages`와 새 message를 합치는 규칙이다.
# 2. `chatbot`: 복구된 `messages`를 읽어 다음 `AIMessage`를 만드는 Node이다.
# 3. `Checkpointer`: 실행 단계별 State를 `thread_id`에 따라 저장하고 불러오는 객체이다.
# 4. `CompiledStateGraph`: Node·Edge를 실행하고 Checkpointer에 저장 시점을 알려 주는 runtime이다.
#
# ```text
# 새 HumanMessage + thread_id
#             ↓
# Checkpointer가 최신 Checkpoint의 messages 복구
#             ↓
# add_messages로 새 입력 병합 → chatbot ↔ tools
#             ↓
# 실행 단계별 새 Checkpoint 저장 → 최종 State 반환
# ```
#
# ### 1. Checkpoint에 저장할 messages State 규칙 정의하기
#
# Checkpointer가 저장하는 대상은 모델 자체가 아니라 **그래프 State**이다. <br>
# State는 `messages` key 하나만 가지며 사용자·모델·Tool message가 실행 순서대로 들어간다.
#
# - 입력: Checkpoint에서 복구한 기존 `messages`와 Node가 반환한 새 message이다.
# - 변환: `add_messages` reducer가 새 message를 기존 목록 뒤에 병합한다.
# - 출력: 다음 Node와 다음 Turn이 읽을 수 있는 갱신된 `messages`이다.
# - 다음 사용처: Checkpointer가 갱신된 State를 새 Checkpoint로 저장한다.
#
# 같은 `thread_id`의 Checkpoint를 복구한 뒤 새 입력을 넣어도 과거 대화가 사라지지 않는 이유가 이 병합 규칙이다.

# %%
from typing import Annotated, TypedDict

from langchain_core.messages import AnyMessage
from langgraph.graph.message import add_messages

class State(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]

# %% [markdown]
# ### 2. 복구된 대화를 읽는 chatbot Node 정의하기
#
# `chatbot()`은 현재 thread의 `messages`를 모델에 전달하고 새 `AIMessage`를 State update로 반환한다. 뒤에서 `add_node()`로 등록하면 그래프의 Node가 된다.
#
# - 입력: Checkpoint에서 복구된 과거 message와 현재 Turn의 새 `HumanMessage`가 합쳐진 State이다.
# - 변환: `llm_with_tools`가 전체 대화를 읽고 일반 답변 또는 Tool 요청을 만든다.
# - 출력: `add_messages`에 전달할 새 `AIMessage` 하나이다.
# - 다음 사용처: Tool 요청 유무에 따라 Tool Node 또는 종료 경로로 이동하고, 갱신된 State는 Checkpoint에 저장된다.
#
# Node는 Checkpointer를 직접 호출하지 않는다. Node가 State update를 반환하면 LangGraph runtime이 실행 단계의 경계에서 저장을 요청한다. 이 셀은 함수 정의 단계이므로 모델 API는 아직 호출하지 않는다.

# %%
# 전달 받은 State
def chatbot(state:State) -> dict:
    response = llm_with_tools.invoke(state['messages'])

    return {'messages': [response]}

# %% [markdown]
# ### 3. State를 저장할 Checkpointer 만들기
#
#
# ![LangGraph 공식 Checkpoint 구조](https://cdn.jsdelivr.net/gh/goat-skn-ai/image-repo@7f008bd902003af9b0138e956af0be37ffa7a9ff/08_llm/08_langgraph/01_langgraph_basics/04_official_checkpoints.png)
#
# 1. **Graph**: State가 Node와 Edge를 따라 이동한다.
# 2. **Super-step**: 현재 실행할 Node 묶음 하나가 한 단계가 된다. 순차 Node는 각각 별도 단계이다.
# 3. **Checkpoint**: 각 단계 경계에서 State·`next`·ID 등의 snapshot을 저장한다.
# 4. **Thread**: 같은 `thread_id`에 속한 Checkpoint들을 하나의 history로 관리한다.
# 5. **StateSnapshot**: 저장된 Checkpoint를 Python에서 조회할 때 사용하는 객체이다.
#
# 출처: [LangGraph Checkpointers 문서](https://docs.langchain.com/oss/python/langgraph/checkpointers)
#
# ---
#
# `InMemorySaver`는 위 Checkpoint들을 RAM에 저장하는 Checkpointer이다.
#
# - 입력: 컴파일된 그래프가 전달하는 `thread_id`와 실행 단계별 State snapshot이다.
# - 변환: 같은 `thread_id`의 Checkpoint들을 하나의 thread history로 구분해 보관한다.
# - 출력: 다음 호출에서 복구할 최신 Checkpoint와 조회 가능한 StateSnapshot이다.
# - 다음 사용처: `compile(checkpointer=checkpointer)`가 이 객체를 그래프 runtime에 연결한다.
#
# `InMemorySaver()` 객체를 만드는 것만으로는 아무 State도 저장되지 않는다. Python 프로세스가 끝나면 기록도 모두 사라지므로, 재시작 복구가 필요한 운영 서비스에는 PostgresSaver 같은 DB 기반 구현을 사용한다.

# %%
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()

# %% [markdown]
# ### 4. 네 구성 요소를 Persistence가 있는 Tool loop로 조립하기
#
# 이제 앞에서 정의한 부품을 `StateGraph`에 등록하고 Checkpointer와 함께 컴파일한다.
#
# `prebuilt`는 반복해서 사용하는 표준 로직을 LangGraph가 미리 구현해 둔 구성 요소이다.<br>
# `ToolNode`와 `tools_condition`를 직접 구현하지 않고 `langgraph.prebuilt`에서 제공되는 것을 사용한다.
#
# - `State` → `StateGraph(State)`의 공유 데이터 schema이다.
# - `chatbot` → 모델의 다음 행동을 만드는 `"chatbot"` Node이다.
# - `ToolNode(tools)` → 모델의 `tool_calls`를 실제 실행하는 `"tools"` Node이다.
# - `tools_condition` → Tool 실행과 종료 중 다음 경로를 고르는 route function이다.
# - `checkpointer` → `compile(checkpointer=...)`에서 thread별 Persistence를 담당한다.
#
# `ToolNode`와 `tools_condition`은 Tool 실행 흐름을 담당하고, 대화 기억은 `checkpointer`가 담당한다.
#
# ```text
# START → chatbot → tools_condition
#                     ├─ tools → chatbot
#                     └─ END
#
# 각 실행 단계의 State ── checkpointer ──> thread_id별 Checkpoint
# ```
#
# `compile()`의 출력은 실행 가능한 `CompiledStateGraph`이다. 이 셀에서는 구조만 조립하므로 모델·Tool 호출과 Checkpoint 저장은 일어나지 않는다. `checkpointer` 인자를 생략하면 `thread_id`를 전달해도 이전 State가 자동으로 복구되지 않는다.

# %%
from langgraph.graph import END, START, StateGraph

from langgraph.prebuilt import ToolNode, tools_condition

workflow = StateGraph(State) # Builder

# 노드 등록
workflow.add_node('chatbot', chatbot)
workflow.add_node('tools', ToolNode(tools)) # PreBuilt ToolNode

# 엣지 연결
workflow.add_edge(START, 'chatbot')
workflow.add_edge('tools', 'chatbot')

# 조건 분기 설정
workflow.add_conditional_edges(
    'chatbot',      # 분기할 Node
    tools_condition
    # "chatbot" Node에서 반환되는 마지막 AIMessage
    # tool_calls가 있다면 "tools", 없으면 END 반환
)

graph = workflow.compile(
    # 단계별 State를 thread_id 기준 CheckPoint로 저장한다.
    checkpointer=checkpointer
) # 실행 가능한 형태로 변경

display(graph)

# %% [markdown]
# ## thread_id로 실제 저장·복구 흐름 확인하기
#
# 앞의 셀들은 기억에 필요한 규칙과 객체를 정의했다. 이제 `graph.invoke()`를 호출하면 처음으로 모델·Tool loop가 실행되고 Checkpointer가 State를 저장한다.
#
# 각 호출은 다음 순서로 처리된다.
#
# 1. 입력 State update와 `configurable.thread_id`를 받는다.
# 2. 같은 thread의 최신 Checkpoint가 있으면 State를 복구한다.
# 3. `add_messages`가 새 `HumanMessage`를 기존 이력 뒤에 합친다.
# 4. 그래프를 실행하고 단계별 State를 새 Checkpoint로 저장한다.
# 5. 누적된 `messages`를 포함한 최종 State를 반환한다.
#
# ### 1. user1 thread에 첫 번째 Turn 저장하기
#
# **Turn**은 사용자 입력과 그에 대한 모델 응답이 오가는 대화 한 차례이다. 첫 호출의 `thread_id`를 `user1`로 지정하고 이름이 포함된 `HumanMessage`를 전달한다.
#
# 아직 user1의 과거 Checkpoint가 없으므로 새 State에서 시작한다. `graph.invoke()`가 끝나면 실행 단계별 Checkpoint가 user1의 history에 추가되고, 최신 Checkpoint에는 사용자 입력과 모델 응답이 포함된다. 첫 Turn만으로는 기억을 증명할 수 없으므로 다음 셀에서 같은 `thread_id`를 재사용한다.

# %%
from langchain_core.messages import HumanMessage

# CheckPointer가 user1의 저장 위치를 선택하게 하기 위한 설정이다.
user_config = {
    'configurable': {
        'thread_id': 'user1'
    }
}

# llm에게 전달할 첫 메시지(첫 Turn)
user_input = {
    'messages':[HumanMessage(content='반가워. 내 이름은 홍길동이야')]
}

user1_state = graph.invoke(
    user_input, # 초기 state
    config = user_config,
    # 'user1' CheckPoint를 저장하고 불러올 thread 지정
)

user1_state['messages'][-1].content
# Out:
# [{'type': 'text',
#   'text': '다시 만나서 반가워요, 홍길동님! 😊',
#   'annotations': [],
#   'id': 'msg_0a79f4fd98d3b793006a83ee8def6487d09afbe4f547d1cb21',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 2. 같은 user1 thread에서 이전 이름 회상하기
#
# 후속 호출에는 새 질문만 전달한다. 그러나 같은 `user1_config`를 사용하므로 Checkpointer가 user1의 최신 Checkpoint를 불러오고, `add_messages`가 새 질문을 과거 대화 뒤에 병합한다.
#
# - 입력: 이름이 없는 새 질문과 `thread_id="user1"`이다.
# - 변환: user1의 과거 `messages` 복구 → 새 질문 병합 → chatbot 실행 순서이다.
# - 출력: 과거 이름을 근거로 만든 최신 `AIMessage`이다.
# - 다음 사용처: 이번 Turn까지 포함한 State가 user1의 새 Checkpoint로 저장된다.
#
# 답변에 첫 Turn의 이름이 반영되면 모델이 숨겨서 기억한 것이 아니라 **복구된 messages를 다시 읽은 것**이다.

# %%
user_input2 = {
    'messages':[
        HumanMessage(content='내 이름이 뭐라고?')
    ]
}

user1_state = graph.invoke(
    user_input2,
    config = user_config,
)

user1_state['messages'][-1].content
# Out:
# [{'type': 'text',
#   'text': '홍길동님이에요!',
#   'annotations': [],
#   'id': 'msg_0a79f4fd98d3b793006a83efdceb4087d096167fa70c26be8d',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 3. 다른 user2 thread가 분리되는지 확인하기
#
# `thread_id="user2"`는 user1과 다른 Checkpoint history를 가리킨다. 같은 graph와 Checkpointer를 사용해도 `thread_id`가 다르면 user1의 messages를 불러오지 않는다.
#
# - 입력: 이름을 묻는 질문과 새 `thread_id="user2"`이다.
# - 변환: user2의 저장 기록만 조회하며, 기록이 없으므로 새 State에서 그래프를 실행한다.
# - 출력: user1의 이름을 근거로 사용하지 않은 최신 `AIMessage`이다.
# - 다음 사용처: user2의 첫 State가 user1과 별도의 Checkpoint로 저장된다.
#
# user2의 답변이 user1의 이름을 근거로 사용하지 않아야 thread 격리가 유지된 것이다. 단, `thread_id`는 저장 key일 뿐 인증 수단은 아니므로 서비스에서는 접근 권한을 별도로 검사해야 한다.

# %%
user222_config = {
    'configurable': {
        'thread_id': 'user222'
    }
}

user222_input = {
    'messages':[
        HumanMessage(content='내 이름이 뭐라고?')
    ]
}

user222_state = graph.invoke(
    user222_input,
    config = user222_config,
)

user222_state['messages'][-1].content
# Out:
# [{'type': 'text',
#   'text': '아직 이름을 알려주지 않으셔서 몰라요.',
#   'annotations': [],
#   'id': 'msg_0bdef350746b2069006a83f11029f48199b8672d9704c4eb09',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 4. user1 thread로 돌아와 세 번째 Turn 이어 가기
#
# user2 호출 뒤 다시 `user1_config`를 전달한다. Checkpointer는 호출 순서가 아니라 `thread_id`를 기준으로 저장 위치를 선택하므로 user1의 최신 Checkpoint를 다시 복구한다.
#
# - 입력: 새 주제와 이름 회상을 함께 요구하는 질문, `thread_id="user1"`이다.
# - 변환: user1의 두 Turn 복구 → 새 질문 병합 → 그래프 실행 순서이다.
# - 출력: 새 주제와 저장된 이름을 함께 반영한 최신 `AIMessage`이다.
# - 다음 사용처: 세 번째 Turn까지 포함한 State가 user1 history의 최신 Checkpoint가 된다.
#
# 이 결과로 서로 다른 thread의 호출이 중간에 끼어도 user1의 대화가 독립적으로 이어지는지 확인한다.

# %%
user_input3 = {
    'messages':[
        HumanMessage(content='LangGraph 복습 계획 간략히 세우고, 내 이름도 알려줘')
    ]
}

user1_state = graph.invoke(
    user_input3,
    config = user_config,
)

user1_state['messages'][-1].content
# Out:
# [{'id': 'rs_0a79f4fd98d3b793006a83f20d307c87d0ba0eee394b8d8971',
#   'summary': [],
#   'type': 'reasoning',
#   'content': [],
#   'encrypted_content': 'gAAAAABqg_IOfXlXjG4wv5wX0ysUmbmMh5P6QJKFEY41JDLdH47hRumWbmQOq31IX8WlUJsrW3koKVjzsN-os_92bxQFLQK2Np6BG9ytgjGKBLYvXAYeL3rawDSzWQi9zJT0adI_cH5bRT73Frtqqd5TLgLuVn_CXLZEutGJy7nZXhyXW1kSIhr4Cs5NPpuEQBdzl9CPABYUETUF8w7HjplynyxqXcJHDsLk-wqiuS0Mi9b2DbiMFWwtHUtMKO3dnQ81Khqjiy9xh0hklMIDA_CI9J5n1rScUEoiJmqkaHrdU092XjSqIj9mPOS11mn2gpjg63GqtCz5c2hHQFS5RyRF5nETq_2-Z4AY0VP_OGmUN7mHNzBSCAWY-PjJIyoPjTLaa1cvRUcZhInLJTrl_qrwt5M9jovDRvs6KUpTuGQFKaM3EE4Mqso-YL3-jMQV5CLX_MxyF3NSo6ycygaEA3umbswJPiOJUD4tNMQ5uF_wYWEXePj6pYS_3X94xb5fpVCOcJh5lxihT8Kn9q4I46TYS4Y2Ci8iTD-oP-CrPhK5DFcTN6q1kx_1QUNMnJsdyPw4LExR-ZanlPTdIuA9ekmH9bmQuu7IG7cLttq773sd-subS6bldFken-IW54xBPcqW_Efpb0lFTG6wF1Tn8gaH_uV6wOcfD_0KVlZ3PleI2z1xjlHfaaIFzuXUksiYWb7BTny4eP7Wq9TxxyF0P2Yas_pNcXH87wt2zxUBRaQGlzL8AkU3oOGxQy-JNtqta1LUeyG48P-kzlmYKOc2p6tvdWCxWbL29oZUlZSPXOGZSKZ_6qUBK0ssbSis_TFw8eGV7sME8JoPYTAVrMLjKARJpWp7SF8WLhpQ8MZvLLJdhDtjLgaVZvbEQDhGy4gg06PARiE3ywRLwWPYh8Xry9hRXbLB1DWBhFv-503xQm9B_RbooD7v_cU0Z4EZhZbOZQyVAJaSOZCX1GQm5Z1OuaPcCS4ascRs-DYcddlgg_C_A97RzQ4ry-dLLOBTZsFzQ7Xu91yX2ecSJa3jFo1MffqIVwDLDzRZiyTk4iAn_nSj5S4M_5qizxt8rBtLr2R_kwwusCDrbkrjV4uKNfWt81_RseGZd4Ma87H0Cd5N8CXNfKLwzPhy3jqrSAwdsQIGGIcHj8wrLPdJdKTZEb5p-sDFbsH8Ew_KHsG4RkalIefKbdFx9PGpXlmzbXQfOA9zFqvv9ye40AnmBqed_IMU7PRZsL0CyKjuQQUoVReJTRAs_DldPpaMjPyg6ssyQBK4KrtoOlBxq9ojt6MYFR6a5k92Pm6zOXxFRPQ_vd6v0S2PyHmr4B7_F7s='},
#  {'type': 'text',
#   'text': '홍길동님이에요!\n\n### LangGraph 간략 복습 계획\n1. **기초 개념**: Graph, State, Node, Edge 이해  \n2. **간단한 워크플로**: 노드 연결 및 상태 전달 실습  \n3. **조건부 흐름**: 조건에 따른 분기와 반복 구현  \n4. **메모리·체크포인트**: 대화 기록과 상태 저장 복습  \n5. **실전 프로젝트**: 도구를 사용하는 간단한 AI 에이전트 만들기  \n6. **정리**: 자주 쓰는 API와 오류 해결 방법을 요약 노트로 작성',
#   'annotations': [],
#   'id': 'msg_0a79f4fd98d3b793006a83f20d7cd487d0a4e572fb187b378d',
#   'phase': 'final_answer'}]

# %% [markdown]
# ## 저장된 최신 Checkpoint를 StateSnapshot으로 확인하기
#
# **Checkpoint**는 Checkpointer에 저장된 기록이고, **StateSnapshot**은 그 기록을 Python에서 조회할 때 받는 객체이다. `graph.get_state(user1_config)`는 user1 thread의 **최신 Checkpoint 하나**를 StateSnapshot으로 반환한다.
#
# **두 필드 확인**
#
# - `values`: 해당 시점의 실제 State 값이다. 여기에는 누적된 `messages`가 들어 있다.
# - `next`: 다음에 실행할 Node 이름의 tuple이다. 그래프가 정상 종료되었으면 빈 tuple `()`이고, 값이 남아 있으면 중단되었거나 이어서 실행할 Node가 있다는 뜻이다.
#
# 입력은 `thread_id="user1"`인 config이고, 출력은 조회 전용 StateSnapshot이다.
#
# ### history와 resume의 범위
#
# - `graph.get_state()`: thread의 최신 snapshot 하나를 조회한다.
# - `graph.get_state_history()`: 같은 thread에 쌓인 여러 snapshot을 순서대로 조회할 때 사용하는 별도 API이다. 이 실습에서는 호출하지 않는다.
# - 같은 `thread_id`의 새 `graph.invoke()`: 최신 State를 복구한 뒤 새 Turn을 실행하는 **대화 이어가기**이다.
# - `Command(resume=...)`: interrupt로 멈춘 실행에 사람의 값을 전달해 재개하는 **중단 지점 resume**이다. 다음 Human-in-the-loop 노트북에서 다룬다.
#
# Tool 호출 여부에 따라 message 수는 달라질 수 있으므로 고정 숫자보다 user1의 세 Turn이 순서대로 포함되는지를 확인한다.

# %%
user1_snapshot = graph.get_state(user_config)

print('message count', len(user1_snapshot.values['messages']))

print('next nodes: ', user1_snapshot.next)
# Out:
# message count 8
# next nodes:  ()

# %%
# 도구 호출 후 내역을 checkpoint
user_input4 = {
    'messages':[
        HumanMessage(
            content='리센느가 누구야?'
        )
    ]
}

user1_state = graph.invoke(
    user_input4,
    config = user_config,
)

user1_state['messages'][-1].text
# Out:
# '보통 **리센느(RESCENE)**는 2024년 3월 26일 데뷔한 **5인조 다국적 K-pop 걸그룹**을 말해요. 소속사는 **더뮤즈엔터테인먼트**이며, 멤버는 **원이, 리브, 미나미, 메이, 제나**입니다. 대표곡으로는 **〈UhUh〉, 〈YoYo〉, 〈Glow Up〉** 등이 있어요. 이름은 **“Re:Scene”**, 즉 장면을 다시 떠올린다는 의미를 담고 있습니다. \ue200cite\ue202turn1search0\ue201'

# %%
user1_snapshot = graph.get_state(user_config)

display(user1_snapshot.values['messages'])
# Out:
# [HumanMessage(content='반가워. 내 이름은 홍길동이야', additional_kwargs={}, response_metadata={}, id='13772855-683c-44f4-94f0-0dc88dc7ef30'),
#  AIMessage(content=[{'type': 'text', 'text': '반가워요, 홍길동님! 무엇을 도와드릴까요?', 'annotations': [], 'id': 'msg_0a79f4fd98d3b793006a83ee20d51887d0ae6b4344216dc6e8', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0a79f4fd98d3b793006a83ee1ff42487d0b46a77db3b95b7be', 'created_at': 1787031071.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0a79f4fd98d3b793006a83ee1ff42487d0b46a77db3b95b7be', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1181, 'output_tokens': 22, 'total_tokens': 1203, 'input_token_details': {'cache_creation': 1178, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='반가워. 내 이름은 홍길동이야', additional_kwargs={}, response_metadata={}, id='6eb7a269-0dad-47a2-8fe4-06beebe638fe'),
#  AIMessage(content=[{'type': 'text', 'text': '다시 만나서 반가워요, 홍길동님! 😊', 'annotations': [], 'id': 'msg_0a79f4fd98d3b793006a83ee8def6487d09afbe4f547d1cb21', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0a79f4fd98d3b793006a83ee8d24ec87d09a2ca7a38f46c59e', 'created_at': 1787031181.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0a79f4fd98d3b793006a83ee8d24ec87d09a2ca7a38f46c59e', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1221, 'output_tokens': 19, 'total_tokens': 1240, 'input_token_details': {'cache_creation': 40, 'cache_read': 1178}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='내 이름이 뭐라고?', additional_kwargs={}, response_metadata={}, id='3b45896f-8851-4563-b6a2-03dd23211790'),
#  AIMessage(content=[{'type': 'text', 'text': '홍길동님이에요!', 'annotations': [], 'id': 'msg_0a79f4fd98d3b793006a83efdceb4087d096167fa70c26be8d', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0a79f4fd98d3b793006a83efdc5d5087d086d47a2dc026602a', 'created_at': 1787031516.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0a79f4fd98d3b793006a83efdc5d5087d086d47a2dc026602a', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1252, 'output_tokens': 11, 'total_tokens': 1263, 'input_token_details': {'cache_creation': 31, 'cache_read': 1218}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간략히 세우고, 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='3d9f798b-264d-455d-9efa-d23f68377aa6'),
#  AIMessage(content=[{'id': 'rs_0a79f4fd98d3b793006a83f20d307c87d0ba0eee394b8d8971', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_IOfXlXjG4wv5wX0ysUmbmMh5P6QJKFEY41JDLdH47hRumWbmQOq31IX8WlUJsrW3koKVjzsN-os_92bxQFLQK2Np6BG9ytgjGKBLYvXAYeL3rawDSzWQi9zJT0adI_cH5bRT73Frtqqd5TLgLuVn_CXLZEutGJy7nZXhyXW1kSIhr4Cs5NPpuEQBdzl9CPABYUETUF8w7HjplynyxqXcJHDsLk-wqiuS0Mi9b2DbiMFWwtHUtMKO3dnQ81Khqjiy9xh0hklMIDA_CI9J5n1rScUEoiJmqkaHrdU092XjSqIj9mPOS11mn2gpjg63GqtCz5c2hHQFS5RyRF5nETq_2-Z4AY0VP_OGmUN7mHNzBSCAWY-PjJIyoPjTLaa1cvRUcZhInLJTrl_qrwt5M9jovDRvs6KUpTuGQFKaM3EE4Mqso-YL3-jMQV5CLX_MxyF3NSo6ycygaEA3umbswJPiOJUD4tNMQ5uF_wYWEXePj6pYS_3X94xb5fpVCOcJh5lxihT8Kn9q4I46TYS4Y2Ci8iTD-oP-CrPhK5DFcTN6q1kx_1QUNMnJsdyPw4LExR-ZanlPTdIuA9ekmH9bmQuu7IG7cLttq773sd-subS6bldFken-IW54xBPcqW_Efpb0lFTG6wF1Tn8gaH_uV6wOcfD_0KVlZ3PleI2z1xjlHfaaIFzuXUksiYWb7BTny4eP7Wq9TxxyF0P2Yas_pNcXH87wt2zxUBRaQGlzL8AkU3oOGxQy-JNtqta1LUeyG48P-kzlmYKOc2p6tvdWCxWbL29oZUlZSPXOGZSKZ_6qUBK0ssbSis_TFw8eGV7sME8JoPYTAVrMLjKARJpWp7SF8WLhpQ8MZvLLJdhDtjLgaVZvbEQDhGy4gg06PARiE3ywRLwWPYh8Xry9hRXbLB1DWBhFv-503xQm9B_RbooD7v_cU0Z4EZhZbOZQyVAJaSOZCX1GQm5Z1OuaPcCS4ascRs-DYcddlgg_C_A97RzQ4ry-dLLOBTZsFzQ7Xu91yX2ecSJa3jFo1MffqIVwDLDzRZiyTk4iAn_nSj5S4M_5qizxt8rBtLr2R_kwwusCDrbkrjV4uKNfWt81_RseGZd4Ma87H0Cd5N8CXNfKLwzPhy3jqrSAwdsQIGGIcHj8wrLPdJdKTZEb5p-sDFbsH8Ew_KHsG4RkalIefKbdFx9PGpXlmzbXQfOA9zFqvv9ye40AnmBqed_IMU7PRZsL0CyKjuQQUoVReJTRAs_DldPpaMjPyg6ssyQBK4KrtoOlBxq9ojt6MYFR6a5k92Pm6zOXxFRPQ_vd6v0S2PyHmr4B7_F7s='}, {'type': 'text', 'text': '홍길동님이에요!\n\n### LangGraph 간략 복습 계획\n1. **기초 개념**: Graph, State, Node, Edge 이해  \n2. **간단한 워크플로**: 노드 연결 및 상태 전달 실습  \n3. **조건부 흐름**: 조건에 따른 분기와 반복 구현  \n4. **메모리·체크포인트**: 대화 기록과 상태 저장 복습  \n5. **실전 프로젝트**: 도구를 사용하는 간단한 AI 에이전트 만들기  \n6. **정리**: 자주 쓰는 API와 오류 해결 방법을 요약 노트로 작성', 'annotations': [], 'id': 'msg_0a79f4fd98d3b793006a83f20d7cd487d0a4e572fb187b378d', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0a79f4fd98d3b793006a83f20c759087d081722b36082438e1', 'created_at': 1787032076.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0a79f4fd98d3b793006a83f20c759087d081722b36082438e1', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1286, 'output_tokens': 175, 'total_tokens': 1461, 'input_token_details': {'cache_creation': 34, 'cache_read': 1249}, 'output_token_details': {'reasoning': 28}}),
#  HumanMessage(content='리센느가 누구야?', additional_kwargs={}, response_metadata={}, id='0614e755-2cfc-4e34-a725-7062b79cb749'),
#  AIMessage(content=[{'id': 'rs_0a79f4fd98d3b793006a83f76a115087d0b49cac59dba19e67', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_druv_HMJeB_-NQ3OjbS56eN5YMBF5Mbbo_TgT0NnvCQwCG0UFZcovrP30whNWg4idB2J44jll_70kjG88vY3adj6gYu4EGVQhvzAbpvDQvstyeaaLz9F69SUPtgLc3fCV6r4EIuRWzCPtcMzLH9vrkpJYCS_P_n0yUCQAU_nN7NzYUTGwQFZGtDFADRYzVRfyHR8FtMM7dZ9S0ClXGzKhCHATb3mFJ0SSudcz2By40SDpRQF6TfM5WO_dFDd9Ug4vHDzhd6C5lUeKmPdz1toMozU8-J3M2k_GQxmqkp7Xl-YCa7zj7ipl_APiLJLa26wk0rt-Qe8HSFItFKQdBkGG3KXR0PxCENDv9QXQM1K4FgcJ8cX_RsWrhmGMG02gQArmijJAlbZpF_7RxOpqUmi1xgvDdWP4VMTSYMyH4F6Ba95sP2g_KuKIX0GUwb_m3PLf4YTPD406bxoOqYL4kWi36C9MC2BEGrYrQ6JEBSQzk7_e8Be1O7zpSEgjJIIsmNsPVSnfo8UR9RDwJTXwQ0IXbOduyKVHqYn-P2KYl-7jqrZBqIryQvnHQUOraRQ0ay2I8H2zoltlpiNWaF9dFpl_1gxRMktkF2gPF-xZ5HOU4s8raHPIHJjbMPgU2DaDankoy7a29h1FRrgpBzFoLAiSmSKgNAt7xzh8rrSAxNkRoPPk2bQQ5OCrrhDo61W9qDFipmMNl6gFl4wYy1Ge1t18mhb6TKepun73U2sgd_wK9OxGiQ5_wahAqIRArchOuAZg3HE2fQfqCrIlZ0vxup4Nt8y231-NOX3iz0AqtMIL7KkwfWN1slkI0HopcQvotcJ8ulM6nP-di1b0R22ejgvFnworPIt3LV4BkpfJQEoIp7Ymue2sLpM2XWkW2VvxCa3DTzyPEc4c8z_VWhGtc_HeW77kmUWF87nC55KvxP4CNYNl_cFRr35ZCd3RMlOPbLtyMNoURrzWaO3Zoraw38IZYTYK4DLGNwi8tTtyH5-zY4C7dVxqSWscOW-P9jS6hDaRADtr-DWNo_QqiyX_sjkpLNlcseQwrvyORCP3DDXYiZgItVFvCaUv54LJjGDBi0CTAZt-_rOKB40i9TKX5X0Wtv43CdDIZ3c-zuMRRNQ-woR0k17ruauFEOcWB5QRw13SmKfugEIzXsryuIJddUt_rdEiqyu7YuV9lP35F7SaxPuP7araVy1RjtjnmDAToImarC6v9SzRDR9YMhjtXiSDHyV2QTxs4lgP6kTwkvEZj_onYAV4OA6ymtQtzgMeDKLV-BoEDZoBi2e1iR8I28JGYiqSdzfm74jXZFVuKPJ7thnrs2FVb88RgCT7bzj0SAxfJN0DTJukMHmjKwGt1bJVoLAYbLaduWWxcsi--MoQwsxzWORnkKyeyfJEJprJ2Y7Xze-NiJLVmN4ZIa40XRh9d9i8UpwFCDvSbw9eWSZOv6iY='}, {'arguments': '{"query":"리센느 RESCENE 누구 그룹 공식 프로필 데뷔 멤버 소속사","include_domains":["rescene-official.com","the-music.com","n.news.naver.com"],"exclude_domains":[],"search_depth":"basic","include_images":false,"time_range":null,"topic":"general","start_date":null,"end_date":null}', 'call_id': 'call_1TM6YHhEr4p1A5afvCx8j3GD', 'name': 'tavily_search', 'type': 'function_call', 'id': 'fc_0a79f4fd98d3b793006a83f76ad6c087d0a66d0a83b5448bbd', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0a79f4fd98d3b793006a83f769332887d0aeab5ffbfb7d2ef9', 'created_at': 1787033449.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0a79f4fd98d3b793006a83f769332887d0aeab5ffbfb7d2ef9', tool_calls=[{'name': 'tavily_search', 'args': {'query': '리센느 RESCENE 누구 그룹 공식 프로필 데뷔 멤버 소속사', 'include_domains': ['rescene-official.com', 'the-music.com', 'n.news.naver.com'], 'exclude_domains': [], 'search_depth': 'basic', 'include_images': False, 'time_range': None, 'topic': 'general', 'start_date': None, 'end_date': None}, 'id': 'call_1TM6YHhEr4p1A5afvCx8j3GD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1474, 'output_tokens': 146, 'total_tokens': 1620, 'input_token_details': {'cache_creation': 188, 'cache_read': 1283}, 'output_token_details': {'reasoning': 51}}),
#  ToolMessage(content='{"query": "리센느 RESCENE 누구 그룹 공식 프로필 데뷔 멤버 소속사", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://n.news.naver.com/entertain/article/396/0000641169", "title": "루네이트, 멤버 3명 추가 공개…데뷔 열기 뜨겁다", "content": "Title: 루네이트, 멤버 3명 추가 공개…데뷔 열기 뜨겁다\\n# NAVER엔터. ## 루네이트, 멤버 3명 추가 공개…데뷔 열기 뜨겁다. 루네이트(LUN8)가 세 명의 멤버를 추가로 공개했다. 루네이트는 지난 6일과 7일, 10일에 공식 SNS와 유튜브 채널을 통해 멤버 진수, 은섭, 카엘의 개인 아이덴티티 필름 및 프로필 이미지를 순차적으로 공개했다. 진수는 루네이트에서 리더 겸 메인 보컬을 맡는다. 아이덴티티 필름 속 진수는 팀 플레이 전략으로 상대 농구팀의 수비를 돌파하고, 포커 중 히든카드인 조커로 자신의 아이덴티티를 나타냈다. 프로필 이미지를 채운 진수의 차분한 카리스마도 눈길을 사로잡았다. 이어 공개된 은섭은 상큼한 비주얼과 훤칠한 피지컬에 뛰어난 가창력을 갖춘 멤버다. 과감한 뱅크 슛을 던지며 아이덴티티 필름에 등장한 은섭은 푸른 잔디 위에서 악보를 그리다 사과를 한입 베어 물었다. 말갛게 핀 미소 너머 단단한 자태를 드러낸 프로필 이미지에서도 은섭만의 생기로운 매력을 단번에 확인할 수 있다. 10일에는 멤버 카엘이 베일을 벗었다. 아이덴티티 필름에서 카엘은 큰 키를 활용한 점프로 레이업 슛을 여유롭게 성공시키는 모습을 선보였다. 특히 밤하늘을 수놓은 불꽃, 투명한 크리스탈과 함께 카엘의 조각 같은 이목구비가 더욱 환하게 돋보였다. 프로필 이미지에도 카엘의 고급스러운 비주얼이 그대로 담겨 이목을 집중시켰다. 앞서 공개된 멤버들에 이어 진수, 은섭, 카엘까지 탄탄한 기량과 개성을 골고루 지닌 멤버들이 루네이트만의 조화로운 케미스트리와 선명한 정체성을 만들어갈 예정이다. 한편, 루네이트는 판타지오에서 7년 만에 새롭게 선보이는 8인조 보이그룹으로 상반기 데뷔를 앞두고 멤버별 프로필을 비롯해 다양한 콘텐츠를 공개하고 있다. 본문의 검색 링크는 AI 자동 인식으로 제공됩니다. 일부에 대해서는 미제공될 수 있고 동일한 명칭이 다수 존재하는 경우에는 전체 검색 결과로 연결될 수 있습니다. * 한진그룹, 인하대병원 치료 중증 어린이 환자 위한 가족 쉼터 마련한다. * (주)한진, 80주년 기념 사내 탁구대회 개최…소통·건강 증진. 무단 전재 및 재배포 금지. 개별 기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. ### 주요뉴스. 해당 언론사에서 선정하며 언론사 페이지(아웃링크)로 이동해 볼 수 있습니다. * 아이유, 회당 출연료 5억 사실 아니다. * 심형탁, \'18세 연하\' 예비 신부 공개 \'예뻐서 죽을 것 같아\'. * \'연예계 대표 글래머\' 강소라, 아찔 화보 비하인드. * 이승기♥이다인 결혼식, 부케의 주인공은? * 현미, 정정하셨는데…안타까운 \'사망 원인\'.", "score": 0.09461931, "raw_content": null, "id": "e992d6-00"}, {"url": "https://n.news.naver.com/article/213/0001384047?type=journalists", "title": "양현석 \\"9월 5인조 신인 데뷔\\"…트레저 이후 6년 만 보이 그룹 [공식]", "content": "Title: 양현석 \\"9월 5인조 신인 데뷔\\"…트레저 이후 6년 만 보이 그룹 [공식]\\n## 양현석 \\"9월 5인조 신인 데뷔\\"…트레저 이후 6년 만 보이 그룹 [공식]. **양현석 YG 총괄 프로듀서가 \'보석함\'을 열었다.** 2026년 하반기 가요계를 뒤흔들 새로운 보이 그룹의 데뷔 로드맵을 발표한 것. YG는 30일 공식 블로그를 통해 공개한 영상에서 양현석의 입을 빌려 신인 보이 그룹 론칭 계획을 구체화했다. **이는 트레저 이후 약 6년 만에 선보이는 YG의 남자 신인 그룹이라는 점에서 전 세계 케이팝 팬들의 기대를 모으고 있다.**. **양현석 총괄은 인터뷰를 통해 \\"지금 예상으로는 9월에 YG의 새로운 남자 그룹을 소개할 생각이다. 많은 분이 궁금해하실 멤버 수는 5명\\"이라고 전격 발표했다.** 다인원 체제로 활동 중인 트레저와 달리, 이번 신인 그룹은 5인조라는 정예 멤버 구성을 택했다. 이는 각 멤버의 개성과 실력을 극대화하여 팀의 완성도를 높이겠다는 YG의 전략적 선택으로 풀이된다. 양 총괄은 또한 \\"YG에서 계획하고 있는 새로운 IP와 신인들에 대해서도 순차적으로 공개해 나가겠다\\"고 덧붙여, 차기 걸그룹 \'넥스트 몬스터(가칭)\'를 포함한 강력한 신인 라인업 구축을 시사했다. 이로써 2026년은 데뷔 20주년을 맞은 빅뱅의 월드투어와 베이비몬스터, 트레저의 활발한 활동에 이어 대형 신인들의 등장까지 더해지며 YG의 미래를 책임질 중요한 분기점이 될 전망이다. 특히 베이비몬스터는 오는 5월 4일 미니 3집 \'춤 (CHOOM)\' 발표를 앞두고 있으며, 양 총괄이 직접 후렴구 안무 작업에 참여하는 등 전폭적인 지원을 아끼지 않고 있다. 트레저 역시 오는 6월 1일 힙합 기반의 새 미니 앨범 발매를 확정 지었다. 양 총괄은 \\"이번 앨범은 개인적으로 가장 마음에 드는 결과물\\"이라며 자신감을 드러냈다. 기존 아티스트들의 탄탄한 행보 위에 9월 5인조 신인 보이 그룹의 데뷔가 더해지며, 2026년 하반기 YG가 그려낼 새로운 청사진에 업계의 관심이 쏠리고 있다. 정대진 기자 / 사진= TV리포트 DB, YG 공식 블로그. 본문의 검색 링크는 AI 자동 인식으로 제공됩니다. 일부에 대해서는 미제공될 수 있고 동일한 명칭이 다수 존재하는 경우에는 전체 검색 결과로 연결될 수 있습니다. * 종영까지 단 \'1회\'→자체 최고 시청률 경신…초유의 반전 피날레 예고한 韓 드라마 (\'닥터신\'). 개별 기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. * 역시 연예인 걱정은 하는 게. 해당 언론사에서 선정하며 언론사 페이지(아웃링크)로 이동해 볼 수 있습니다. * 예매율 1위→역대급 수익 예고…20년 만에 돌아와 극장가 평정한 \'레전드 영화\'. * 전 세계 사로잡은 \'1100만 부\' 베스트셀러가 극장으로…\'K-무비\'로 재탄생한 작품 (\'이상한 과자 가게 전천당\'). * \'시청률 1%대\' 뼈아팠나…돌연 오른팔 잘라내고 판 새로 짠 韓 예능 (\'이숙캠\'). * SBS가 또 해냈다…단 2회 만에 넷플릭스 \'글로벌 2위\' 등극하며 입소문 탄 韓 드라마 (\'오매진\'). * 내리막길→화려한 반등…수도권 접수→2054 시청률 1위까지 휩쓴 韓 예능 (\'놀뭐\').", "score": 0.043548565, "raw_content": null, "id": "272429-01"}], "response_time": 2.6, "request_id": "bc1485c4-7412-491d-85a8-1cae4b96dc60"}', name='tavily_search', id='ef975b27-4405-4e5e-bb33-7edad168d441', tool_call_id='call_1TM6YHhEr4p1A5afvCx8j3GD'),
#  HumanMessage(content='리센느가 누구야?', additional_kwargs={}, response_metadata={}, id='4280ced7-36a4-4f8c-a3a7-c82ff5cd4034'),
#  AIMessage(content=[{'id': 'rs_0a79f4fd98d3b793006a83f77dc62c87d0bffff39f90d08c72', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_d_-GbBVjnkIRUqQ-kXloUQH7ycyFpPtvx1Unu016op-UVpEANzkf8zNg_tD1_CMbtL41lAxvMNYR9pSYGplEsL2LRKq2F7ZlYiQmh70Xg41FBZnKVG6CUICI3qBTtPjZSXYuZXHyxXQUm7Gt-g2T6tnG9uoEsYGA9YiOltDMVbjvA7ZZM9G7BgXGaiwa0t57bxbwjHLjOxLy_iuZhjX89pJKQ-h1FLAsE_OaOQ8HTJC86AGkuCAvYm_UJZLCs4Ak-yqIBfBZ8GbFSh1mWxgOBwZng-kc-GWWqxcA41NeU3s6l-yCvivBc3PEb9GPeSv8nVLt0cQdROBuRBby_nGQAWh83iEp7-U4TDAnLozluxssybThedpGUMkCbzypoQ8V0Hh1uKq5nfi8ajOIe8-9GN0rlUo7n4gAW9namI5o7at2WX3nMERGGyE-zD2tGMrBi1saLbtow17cOo1VLtdx-cfjKHBlfq88P7BfPz3xu9eECl5RueIcbRQdIQo1lSns1LyRoljQQ-p1wb8TRJgioefVf5WvRlyDqqESa47z3pczgvDWAyYspWNLrcLa6LTVMFqPfmvo1GwnxbcLRxtqPR6wS2aWq8zaah2P5v9t1Fg9wlJYERiv8aTRi3UR_qeRsvW8ok4U9NQuPAvbXf64pupoUWcdYDCu0JEavj4svleu6Z2WWjVRCODPmhX1Z3juZACDjGZ68UgYf0u2IYtwLp_wIyBmTAM60E9w5KCBEDKs41yRhi9fhq4i-G5Cs8q9Y6wq2lIzr_TY4-cdMY3Ay9VuWoeUt2IUhvvpaaXTAVDHW0hnWeDFCGpKFjIV0LCupaM7uPdBNJaHdxBdFdEPJOh7faQmfl6N9Q3ud0Hb6bX4aZ4m4HKUEx-NTtD8qxOaygfbyAWPR537HM_r4L5Xm8dIatUKXEeP3yT0zdthihmYSB8T7w2ymNzx-WjgBKwTVwLClLPNwPCyiuc9d08MyvCNfuYmKFVF1_eDv_P1pW0VcwLCW-0arzZdXEWBdImhp26ZfmuUkiB24q3lY6zMyEBq82goq5PEpO9iwl9VJkqWPSU9jgplBhn9vJbnJe-RXpaT2kn3kQMBBAh-VOmbyl6YK-WAUiZj0LnRjutuoRY7uFxT8rV-rcUotslBpNG6NUeYKWF91J6-UOVmhuMPMntO5pfSdNIOF-SeK2JOwKkPbPSgO1lHTss0V6DAnVJcljMqNZe4n22MT8a30c1I79hz9zpPJYXEfmTHJtPQDnkb5fNeCJCnz2Piidfi2l1CtJxMXeKmsPLiy-ABM_rmfK1rFBxbbzCLb5r9gkxukqjFkJEJj18FTrS41evHf4ALKwR9OF67js_L_R8rzMNrbKiQ=='}, {'arguments': '{"query":"RESCENE 리센느 걸그룹 멤버 데뷔 2024 더뮤직웍스 공식","include_domains":["namu.wiki","kprofiles.com","sports.donga.com","newsis.com"],"exclude_domains":[],"search_depth":"advanced","include_images":false,"time_range":null,"topic":"general","start_date":null,"end_date":null}', 'call_id': 'call_O2kJaSeavpRTRVMABlcC9nM7', 'name': 'tavily_search', 'type': 'function_call', 'id': 'fc_0a79f4fd98d3b793006a83f77e44a887d0a1e9b83b9216af22', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0a79f4fd98d3b793006a83f77cfd8087d0b8041cca5f657a29', 'created_at': 1787033469.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0a79f4fd98d3b793006a83f77cfd8087d0b8041cca5f657a29', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'RESCENE 리센느 걸그룹 멤버 데뷔 2024 더뮤직웍스 공식', 'include_domains': ['namu.wiki', 'kprofiles.com', 'sports.donga.com', 'newsis.com'], 'exclude_domains': [], 'search_depth': 'advanced', 'include_images': False, 'time_range': None, 'topic': 'general', 'start_date': None, 'end_date': None}, 'id': 'call_O2kJaSeavpRTRVMABlcC9nM7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3760, 'output_tokens': 131, 'total_tokens': 3891, 'input_token_details': {'cache_creation': 11, 'cache_read': 3746}, 'output_token_details': {'reasoning': 30}}),
#  ToolMessage(content='{"query": "RESCENE 리센느 걸그룹 멤버 데뷔 2024 더뮤직웍스 공식", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://namu.wiki/w/RESCENE", "title": "RESCENE - 나무위키", "content": "1. 개요2. 멤버\\n\\n2.1. 멤버 간 케미\\n\\n3. 특징\\n\\n3.1. 로고3.2. 그룹명3.3. 콘셉트3.4. 비주얼\\n\\n4. 음반5. 뮤직비디오6. 활동\\n\\n6.1. 콘텐츠6.2. 공연 및 행사6.3. 음악 방송\\n\\n6.3.1. 직캠\\n\\n6.4. 광고 및 화보·홍보대사6.5. YouTube LIVE\\n\\n7. 팬덤\\n\\n7.1. 응원법7.2. 굿즈\\n\\n8. 수상\\n\\n8.1. 상세 음원 성적\\n\\n9. 여담10. 역대 프로필 사진11. 둘러보기\\n\\n## 1.개요(\\n\\nVideo 1\\n\\n인사드리겠습니다. 둘, 셋!(원이 선창) 안녕하세요, RESCENE입니다!\\n\\n2024년3월 26일에 데뷔한 더뮤즈엔터테인먼트 소속 5인조 다국적 걸그룹.( \\"한국인 4명(원이, 리브, 메이, 제나)과 일본인 1명(미나미)으로 구성되어 있다.\\")\\n\\n## 2.멤버(\\n\\nImage 137Image 138: Pretty Girl 원이 프...Image 140Image 141: Pretty Girl 리브 프... \\"리브(RESCENE)\\")Image 143Image 144: Pretty Girl 미나미 ... \\"미나미(RESCENE)\\")Image 146Image 147: Pretty Girl 메이 프... \\"메이(RESCENE)\\")Image 149Image 150: Pretty Girl 제나 프...\\n원이리브 \\"리브(RESCENE)\\")미나미 \\"미나미(RESCENE)\\")메이 \\"메이(RESCENE)\\")제나\\n2004. 05. 25. (22세)\\n\\n  \\n\\nImage 152Image 153: 대한민국 국기2006. 10. 11. (19세) [...] 리센느\\n데뷔일2024년3월 26일\\n\\n(데뷔일로부터 +868일, 2주년)\\n데뷔 음반싱글 1집\\n\\nRe:Scene\\n장르K-POP, 댄스, 팝, R&B / Soul, 발라드\\n리더원이\\n소속사더뮤즈엔터테인먼트\\n레이블Image 77Image 78: 일본 국기ADA Japan\\n유통사Image 80Image 81: 대한민국 국기KT지니뮤직｜스톤뮤직( \\"YoYo부터 lip bomb 시기까지는 카카오엔터테인먼트였다.\\")\\nImage 83Image 84: 일본 국기워너 뮤직 재팬\\n팬덤REMINE (리마인)\\n링크⠀[ 펼치기 · 접기 ] 공식 사이트 Image 86Image 87: 대한민국 국기Image 89Image 90: RESCENE 심볼Image 92Image 93: RESCENE 심볼 화이트 ｜Image 95Image 96: 플러스챗 심볼 공식 SNS Image 98Image 99: 대한민국 국기Image 101Image 102: X Corp 아이콘(블랙)｜Image 104Image 105: X Corp 아이콘(블랙)멤버｜Image 107Image 108: 페이스북 아이콘｜Image 110Image 111: 인스타그램 아이콘｜Image 113Image 114: 유튜브 아이콘 Image 116Image 117: 틱톡 아이콘｜Image 119Image 120: 네이버 클립 아이콘 Image 122Image 123: 중국 국기Image 125Image 126: 시나 웨이보 아이콘｜Image 128Image 129: 빌리빌리 아이콘｜Image 131Image 132: 틱톡 아이콘｜Image 134Image 135: 샤오홍슈 아이콘 [...] 최근 변경최근 토론\\n\\n특수 기능\\n\\n\\n\\n\\n\\n여야 합니다. 해당 문서의 ACL 탭을 확인하시기 바랍니다.\\n\\n닫기 \\n\\n토론역사\\n\\n분류\\n   RESCENE\\n   대한민국의 걸그룹\\n   5인조 음악 그룹\\n   2024년 데뷔\\n   2024년 결성된 음악 그룹\\n   유튜브 공식 아티스트 채널\\n   Spotify 인증 아티스트\\n   엠넷플러스 입점 아티스트\\n   Dear U bubble 입점 아티스트\\n   인터넷 밈/가수/대한민국\\n\\nImage 2Image 3: RESCENE 로고(Prett... RESCENE 리센느\\n\\n원이\\n\\n리브 \\"리브(RESCENE)\\")\\n\\n미나미 \\"미나미(RESCENE)\\")\\n\\n메이 \\"메이(RESCENE)\\")\\n\\n제나\\n\\n( 해외 음반 ]]( 기타 음반 ]]( 관련 문서 ]](", "score": 0.8687491, "raw_content": null, "id": "b42d2b-00"}, {"url": "https://namu.wiki/w/RESCENE/%EC%9D%8C%EC%95%85%20%EB%B0%A9%EC%86%A1", "title": "RESCENE/음악 방송", "content": "메이 \\"메이(RESCENE)\\")\\n\\n제나\\n\\n( 해외 음반 ]]( 기타 음반 ]]( 관련 문서 ]](\\n\\nImage 8Image 9: YoYoImage 11Image 12: Re:SceneImage 14Image 15: SCENEDROMEImage 17Image 18: glow up digital ...\\nYoYo 선공개 싱글 2024. 02. 29.Re:Scene 싱글 1집 2024. 03. 26.SCENE\u200bDROME 미니 1집 2024. 08. 27.Glow Up 미니 2집 2025. 02. 05.\\nImage 20Image 21: Dearest(RESCENE) \\"Dearest(RESCENE)\\")Image 23Image 24: Heart DropImage 26Image 27: lip bombImage 29Image 30: Runaway(RESCENE) \\"Runaway(RESCENE)\\")\\nDearest 싱글 2집 2025. 07. 02. \\"Dearest(RESCENE)\\")Heart Drop 선공개 싱글 2025. 11. 06.lip bomb 미니 3집 2025. 11. 25.Runaway 디지털 싱글 2026. 04. 08. \\"Runaway(RESCENE)\\")\\nImage 32Image 33: Pretty Girl(RESC... \\"Pretty Girl(RESCENE)\\")\\nPretty Girl 스페셜 싱글 2026. 07. 08. \\"Pretty Girl(RESCENE)\\")\\n\\n( 영어 음반 ]]( [...] ( 영어 음반 ]](\\n\\nImage 35Image 36: YoYo (Japanese V... \\"YoYo (Japanese Version)\\")Image 38Image 39: UhUh (Japanese V... \\"UhUh (Japanese Version)\\")Image 41Image 42: Pinball(Japanese... \\"ピンボール (Pinball)\\")\\nYoYo (Japanese Version) 디지털 싱글 2024. 08. 16. \\"YoYo (Japanese Version)\\")UhUh (Japanese Version) 디지털 싱글 2024. 12. 04. \\"UhUh (Japanese Version)\\")ピンボール (Pinball) 디지털 싱글 2026. 01. 21. \\"ピンボール (Pinball)\\")\\n\\nImage 44Image 45: Glow Up (English... \\"Glow Up (English Version)\\")\\nGlow Up (English Version) 디지털 싱글 2025. 02. 17. \\"Glow Up (English Version)\\")\\n\\n( 참여 음반 ]] ...
#  AIMessage(content=[{'type': 'text', 'text': '보통 **리센느(RESCENE)**는 2024년 3월 26일 데뷔한 **5인조 다국적 K-pop 걸그룹**을 말해요. 소속사는 **더뮤즈엔터테인먼트**이며, 멤버는 **원이, 리브, 미나미, 메이, 제나**입니다. 대표곡으로는 **〈UhUh〉, 〈YoYo〉, 〈Glow Up〉** 등이 있어요. 이름은 **“Re:Scene”**, 즉 장면을 다시 떠올린다는 의미를 담고 있습니다. \ue200cite\ue202turn1search0\ue201', 'annotations': [], 'id': 'msg_0a79f4fd98d3b793006a83f7849c0487d09b65fc5b0adb891e', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0a79f4fd98d3b793006a83f783e5cc87d0a4eaff64a53a2c31', 'created_at': 1787033476.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0a79f4fd98d3b793006a83f783e5cc87d0a4eaff64a53a2c31', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6267, 'output_tokens': 150, 'total_tokens': 6417, 'input_token_details': {'cache_creation': 2507, 'cache_read': 3757}, 'output_token_details': {'reasoning': 0}})]
